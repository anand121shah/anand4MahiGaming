# %% [markdown]
# <a href="https://colab.research.google.com/github/as-bestinclass/anand4MahiGaming/blob/main/Scenario_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as pyplt
import matplotlib.dates as mdates
import seaborn as sborn
from wordcloud import WordCloud
import warnings
from statsmodels.tools.sm_exceptions import ValueWarning
warnings.filterwarnings("ignore", category=ValueWarning)

# %% [markdown]
# ##LOADING RAW DATA

# %%
GameAttributes_DF = pd.read_csv('/content/GameAttributes.csv')
GameAttributes_DF
# Out:
#                        Game_Name  Provider Release_Date               Type  \
# 0          Game King Video Poker       IGT   2019-06-13         Card games
# 1              Heads Up Hold' em  Playtech   2019-09-25  Live Casino Games
# 2  Premium Blackjack Single Hand  Playtech   2017-08-15         Card games
# 3               Quantum Roulette  Playtech   2019-08-20  Live Casino Games
# 4                   101 Roulette  Playtech   2018-12-13     Roulette Games
#
#       RTP Variance  Hit_Frequency  Max_Win  Min_Bet  Max_Bet Layout  Betways  \
# 0  99.16%      Med            NaN  x800.00      0.1    100.0    N-A      NaN
# 1  97.64%      NaN            NaN        0      0.0      0.0    N-A      NaN
# 2  98.58%      NaN            NaN  x100.00      1.0   1000.0    N-A      NaN
# 3  97.31%      NaN            NaN      NaN      NaN      NaN    N-A      NaN
# 4  96.19%      NaN            NaN        0      0.0      0.0    N-A      NaN
#
#     Features                                           Theme      Objects  \
# 0        NaN  Card Game, Card theme, Poker-Game, Video poker          NaN
# 1        NaN                           Card Game, Poker-Game  Table games
# 2  RTP range                                       Card Game          NaN
# 3        NaN                                   Roulette-Game  Table games
# 4  RTP range                                   Roulette-Game          NaN
#
#                                  Genre        Other_Tags  Technology  \
# 0                                  NaN         JS, HTML5         NaN
# 1  Black, Red, Card, Chip, Live Casino         JS, HTML5         NaN
# 2                Blackjack, Card, Chip  FLASH, JS, HTML5         NaN
# 3                Live Casino, Roulette         JS, HTML5         NaN
# 4                           Green, Red         JS, HTML5         NaN
#
#   Last_Update
# 0  2022-04-30
# 1  2019-10-01
# 2  2023-03-18
# 3  2023-03-07
# 4  2019-04-26

# %%
CountryData_DF = pd.read_csv('/content/CountryData.csv')
CountryData_DF
# Out:
#                         Game_Name           Country  Scanned  With_Game  \
# 0           Game King Video Poker           Ireland      307         12
# 1           Game King Video Poker    United Kingdom      577         10
# 2           Game King Video Poker            Sweden       99          5
# 3           Game King Video Poker  Canada (Ontario)       16          4
# 4               Heads Up Hold' em            Norway      465         47
# 5               Heads Up Hold' em           Finland      593         43
# 6               Heads Up Hold' em       New Zealand      484         39
# 7               Heads Up Hold' em            Brazil      244         33
# 8   Premium Blackjack Single Hand            Canada      644         68
# 9   Premium Blackjack Single Hand           Finland      593         52
# 10  Premium Blackjack Single Hand            Norway      465         52
# 11  Premium Blackjack Single Hand       New Zealand      484         45
# 12               Quantum Roulette            Canada      644        122
# 13               Quantum Roulette           Finland      593        106
# 14               Quantum Roulette    United Kingdom      577         96
# 15               Quantum Roulette       New Zealand      484         94
# 16                   101 Roulette            Canada      644         29
# 17                   101 Roulette            Norway      465         20
# 18                   101 Roulette       New Zealand      484         17
# 19                   101 Roulette           Finland      593         17
#
#     In_Lobby  SlotRank
# 0          2      1432
# 1          0      5424
# 2          1       301
# 3          1       101
# 4          2       684
# 5          2      1291
# 6          0     10938
# 7          0      9941
# 8          0      9196
# 9          2      1079
# 10         2       880
# 11         0     10190
# 12         1      1452
# 13         1      2258
# 14         9        49
# 15         0      6799
# 16         0     12097
# 17         0     12596
# 18         0     14850
# 19         0     14146

# %%
SlotRank_DF = pd.read_csv('/content/SlotRank.csv')
SlotRank_DF
# Out:
#    SlotRank_Place                      Game_Name  Provider  \
# 0               1          Game King Video Poker       IGT
# 1               2              Heads Up Hold' em  Playtech
# 2               3  Premium Blackjack Single Hand  Playtech
# 3               4               Quantum Roulette  Playtech
# 4               5                   101 Roulette  Playtech
#
#    Average_Position_in_Lobby  Found_in_Casinos
# 0                      137.5                 3
# 1                      138.1                 2
# 2                      138.5                 2
# 3                      138.8                 1
# 4                      139.0                 3

# %% [markdown]
# ##DATA PREPROCESSING

# %% [markdown]
# ##### Dataframe Preprocess

# %%
GameAttributes_DF = pd.read_csv('/content/GameAttributes.csv')

# validating the data in date-time format
GameAttributes_DF['Release_Date'] = pd.to_datetime(GameAttributes_DF['Release_Date'])
GameAttributes_DF['Last_Update'] = pd.to_datetime(GameAttributes_DF['Last_Update'])

# dropping columns to cleanup data
GameAttributes_DF.dropna(thresh=3, axis=1, inplace=True)
GameAttributes_DF.drop(['Max_Win', 'Min_Bet', 'Max_Bet', 'Layout'], axis=1, inplace=True)

GameAttributes_DF
# Out:
#                        Game_Name  Provider Release_Date               Type  \
# 0          Game King Video Poker       IGT   2019-06-13         Card games
# 1              Heads Up Hold' em  Playtech   2019-09-25  Live Casino Games
# 2  Premium Blackjack Single Hand  Playtech   2017-08-15         Card games
# 3               Quantum Roulette  Playtech   2019-08-20  Live Casino Games
# 4                   101 Roulette  Playtech   2018-12-13     Roulette Games
#
#       RTP                                           Theme  \
# 0  99.16%  Card Game, Card theme, Poker-Game, Video poker
# 1  97.64%                           Card Game, Poker-Game
# 2  98.58%                                       Card Game
# 3  97.31%                                   Roulette-Game
# 4  96.19%                                   Roulette-Game
#
#                                  Genre        Other_Tags Last_Update
# 0                                  NaN         JS, HTML5  2022-04-30
# 1  Black, Red, Card, Chip, Live Casino         JS, HTML5  2019-10-01
# 2                Blackjack, Card, Chip  FLASH, JS, HTML5  2023-03-18
# 3                Live Casino, Roulette         JS, HTML5  2023-03-07
# 4                           Green, Red         JS, HTML5  2019-04-26

# %%
print('Total number of features in the Game Attributes are: ', GameAttributes_DF.shape[1])
# Out:
# Total number of features in the Game Attributes are:  9

# %% [markdown]
# ##### Combined Dataframe

# %%
add = pd.merge(CountryData_DF, SlotRank_DF, on='Game_Name')
Combined_DF = pd.merge(add, GameAttributes_DF, on='Game_Name')
Combined_DF['RTP'] = Combined_DF['RTP'].str.rstrip('%').astype('float') / 100.0

# %% [markdown]
# ### Initial Vizualization

# %%
Combined_DF
# Out:
#                         Game_Name           Country  Scanned  With_Game  \
# 0           Game King Video Poker           Ireland      307         12
# 1           Game King Video Poker    United Kingdom      577         10
# 2           Game King Video Poker            Sweden       99          5
# 3           Game King Video Poker  Canada (Ontario)       16          4
# 4               Heads Up Hold' em            Norway      465         47
# 5               Heads Up Hold' em           Finland      593         43
# 6               Heads Up Hold' em       New Zealand      484         39
# 7               Heads Up Hold' em            Brazil      244         33
# 8   Premium Blackjack Single Hand            Canada      644         68
# 9   Premium Blackjack Single Hand           Finland      593         52
# 10  Premium Blackjack Single Hand            Norway      465         52
# 11  Premium Blackjack Single Hand       New Zealand      484         45
# 12               Quantum Roulette            Canada      644        122
# 13               Quantum Roulette           Finland      593        106
# 14               Quantum Roulette    United Kingdom      577         96
# 15               Quantum Roulette       New Zealand      484         94
# 16                   101 Roulette            Canada      644         29
# 17                   101 Roulette            Norway      465         20
# 18                   101 Roulette       New Zealand      484         17
# 19                   101 Roulette           Finland      593         17
#
#     In_Lobby  SlotRank  SlotRank_Place Provider_x  Average_Position_in_Lobby  \
# 0          2      1432               1        IGT                      137.5
# 1          0      5424               1        IGT                      137.5
# 2          1       301               1        IGT                      137.5
# 3          1       101               1        IGT                      137.5
# 4          2       684               2   Playtech                      138.1
# 5          2      1291               2   Playtech                      138.1
# 6          0     10938               2   Playtech                      138.1
# 7          0      9941               2   Playtech                      138.1
# 8          0      9196               3   Playtech                      138.5
# 9          2      1079               3   Playtech                      138.5
# 10         2       880               3   Playtech                      138.5
# 11         0     10190               3   Playtech                      138.5
# 12         1      1452               4   Playtech                      138.8
# 13         1      2258               4   Playtech                      138.8
# 14         9        49               4   Playtech                      138.8
# 15         0      6799               4   Playtech                      138.8
# 16         0     12097               5   Playtech                      139.0
# 17         0     12596               5   Playtech                      139.0
# 18         0     14850               5   Playtech                      139.0
# 19         0     14146               5   Playtech                      139.0
#
#     Found_in_Casinos Provider_y Release_Date               Type     RTP  \
# 0                  3        IGT   2019-06-13         Card games  0.9916
# 1                  3        IGT   2019-06-13         Card games  0.9916
# 2                  3        IGT   2019-06-13         Card games  0.9916
# 3                  3        IGT   2019-06-13         Card games  0.9916
# 4                  2   Playtech   2019-09-25  Live Casino Games  0.9764
# 5                  2   Playtech   2019-09-25  Live Casino Games  0.9764
# 6                  2   Playtech   2019-09-25  Live Casino Games  0.9764
# 7                  2   Playtech   2019-09-25  Live Casino Games  0.9764
# 8                  2   Playtech   2017-08-15         Card games  0.9858
# 9                  2   Playtech   2017-08-15         Card games  0.9858
# 10                 2   Playtech   2017-08-15         Card games  0.9858
# 11                 2   Playtech   2017-08-15         Card games  0.9858
# 12                 1   Playtech   2019-08-20  Live Casino Games  0.9731
# 13                 1   Playtech   2019-08-20  Live Casino Games  0.9731
# 14                 1   Playtech   2019-08-20  Live Casino Games  0.9731
# 15                 1   Playtech   2019-08-20  Live Casino Games  0.9731
# 16                 3   Playtech   2018-12-13     Roulette Games  0.9619
# 17                 3   Playtech   2018-12-13     Roulette Games  0.9619
# 18                 3   Playtech   2018-12-13     Roulette Games  0.9619
# 19                 3   Playtech   2018-12-13     Roulette Games  0.9619
#
#                                              Theme  \
# 0   Card Game, Card theme, Poker-Game, Video poker
# 1   Card Game, Card theme, Poker-Game, Video poker
# 2   Card Game, Card theme, Poker-Game, Video poker
# 3   Card Game, Card theme, Poker-Game, Video poker
# 4                            Card Game, Poker-Game
# 5                            Card Game, Poker-Game
# 6                            Card Game, Poker-Game
# 7                            Card Game, Poker-Game
# 8                                        Card Game
# 9                                        Card Game
# 10                                       Card Game
# 11                                       Card Game
# 12                                   Roulette-Game
# 13                                   Roulette-Game
# 14                                   Roulette-Game
# 15                                   Roulette-Game
# 16                                   Roulette-Game
# 17                                   Roulette-Game
# 18                                   Roulette-Game
# 19                                   Roulette-Game
#
#                                   Genre        Other_Tags Last_Update
# 0                                   NaN         JS, HTML5  2022-04-30
# 1                                   NaN         JS, HTML5  2022-04-30
# 2                                   NaN         JS, HTML5  2022-04-30
# 3                                   NaN         JS, HTML5  2022-04-30
# 4   Black, Red, Card, Chip, Live Casino         JS, HTML5  2019-10-01
# 5   Black, Red, Card, Chip, Live Casino         JS, HTML5  2019-10-01
# 6   Black, Red, Card, Chip, Live Casino         JS, HTML5  2019-10-01
# 7   Black, Red, Card, Chip, Live Casino         JS, HTML5  2019-10-01
# 8                 Blackjack, Card, Chip  FLASH, JS, HTML5  2023-03-18
# 9                 Blackjack, Card, Chip  FLASH, JS, HTML5  2023-03-18
# 10                Blackjack, Card, Chip  FLASH, JS, HTML5  2023-03-18
# 11                Blackjack, Card, Chip  FLASH, JS, HTML5  2023-03-18
# 12                Live Casino, Roulette         JS, HTML5  2023-03-07
# 13                Live Casino, Roulette         JS, HTML5  2023-03-07
# 14                Live Casino, Roulette         JS, HTML5  2023-03-07
# 15                Live Casino, Roulette         JS, HTML5  2023-03-07
# 16                           Green, Red         JS, HTML5  2019-04-26
# 17                           Green, Red         JS, HTML5  2019-04-26
# 18                           Green, Red         JS, HTML5  2019-04-26
# 19                           Green, Red         JS, HTML5  2019-04-26

# %%
Combined_DF.describe()
# Out:
#          Scanned  With_Game   In_Lobby      SlotRank  SlotRank_Place  \
# count   20.00000   20.00000  20.000000     20.000000       20.000000
# mean   472.75000   45.55000   1.150000   5785.200000        3.000000
# std    177.16358   35.17247   2.033276   5391.043016        1.450953
# min     16.00000    4.00000   0.000000     49.000000        1.000000
# 25%    465.00000   17.00000   0.000000   1029.250000        2.000000
# 50%    484.00000   41.00000   0.500000   3841.000000        3.000000
# 75%    593.00000   56.00000   2.000000  10377.000000        4.000000
# max    644.00000  122.00000   9.000000  14850.000000        5.000000
#
#        Average_Position_in_Lobby  Found_in_Casinos        RTP
# count                  20.000000         20.000000  20.000000
# mean                  138.380000          2.200000   0.977760
# std                     0.548299          0.767772   0.010576
# min                   137.500000          1.000000   0.961900
# 25%                   138.100000          2.000000   0.973100
# 50%                   138.500000          2.000000   0.976400
# 75%                   138.800000          3.000000   0.985800
# max                   139.000000          3.000000   0.991600

# %%
print('GameAttributes_DF columns are ', GameAttributes_DF.columns)
print('\n\nCountryData_DF columns are ', CountryData_DF.columns)
print('\n\nSlotRank_DF columns are ', SlotRank_DF.columns)
print('\n\nCombined_DF columns are ', Combined_DF.columns)
# Out:
# GameAttributes_DF columns are  Index(['Game_Name', 'Provider', 'Release_Date', 'Type', 'RTP', 'Theme',
#        'Genre', 'Other_Tags', 'Last_Update'],
#       dtype='object')
#
#
# CountryData_DF columns are  Index(['Game_Name', 'Country', 'Scanned', 'With_Game', 'In_Lobby', 'SlotRank'], dtype='object')
#
#
# SlotRank_DF columns are  Index(['SlotRank_Place', 'Game_Name', 'Provider', 'Average_Position_in_Lobby',
#        'Found_in_Casinos'],
#       dtype='object')
#
#
# Combined_DF columns are  Index(['Game_Name', 'Country', 'Scanned', 'With_Game', 'In_Lobby', 'SlotRank',
#        'SlotRank_Place', 'Provider_x', 'Average_Position_in_Lobby',
#        'Found_in_Casinos', 'Provider_y', 'Release_Date', 'Type', 'RTP',
#        'Theme', 'Genre', 'Other_Tags', 'Last_Update'],
#       dtype='object')

# %% [markdown]
# ## DATA VIZUALIZATION

# %% [markdown]
# ### 0. Features Correlation Matrix

# %%
# Plotting a 10x5 chart
pyplt.figure(figsize=(10, 5))

# Showing Correlation Between Features of the complete dataset
sborn.heatmap(Combined_DF.corr(numeric_only=True), cmap='coolwarm', annot=True)
pyplt.title("Features Correlation Heatmap")
pyplt.show()

# %% [markdown]
# ### 1. Pie Chart -- MarketShare of each Brand on the Leaderboard

# %% [markdown]
# #### Exhibit A -- MarketShare for Game Providers

# %%
# occurence of brand in the leaderboard
occurence = GameAttributes_DF['Provider'].value_counts()

# Plotting a chart to show marketshare
pyplt.figure(figsize=(5, 5))
pyplt.pie(occurence, labels=occurence.index, autopct='%1.1f%%')
pyplt.title('MarketShare of each Brand on the Leaderboard')
pyplt.show()

# %% [markdown]
# #### Exhibit B -- MarketShare for Game Type

# %%
# occurence of brand in the leaderboard
occurence = GameAttributes_DF['Type'].value_counts()

# Plotting a chart to show marketshare
pyplt.figure(figsize=(5, 5))
pyplt.pie(occurence, labels=occurence.index, autopct='%1.1f%%')
pyplt.title('MarketShare of each type of the Game')
pyplt.show()

# %% [markdown]
# ### 2. Heatmap (Vizualize the intensity of Popularity)

# %%
# Charting the layout
pyplt.figure(figsize=(10, 10))

# Pivoting the Column for the heatmap
the_pivot = pd.pivot_table(Combined_DF, index='Game_Name', values='Scanned', columns='Country', fill_value=0)

# Plotting a heatmap
sborn.heatmap(the_pivot, annot=True, cmap="Greens", cbar=True, square=True, fmt="d")

pyplt.title("Heatmap of Scanned Players by Game and Country\n (Greener means more busier at any given time)\n\n")
pyplt.xlabel("Geographical Locations")
pyplt.ylabel("Slot Games")
pyplt.show()

# %% [markdown]
# ### 3. Box Plot (Range of variance in Return-To-Player Metrics)

# %%
# Defining a BoxPlot
sborn.boxplot(data=Combined_DF, x='Type', y='RTP')

# Adding Chart's Description for interpretation
pyplt.title('Return-To-Player Rate for Each Game Type')
pyplt.ylabel('Rate of Return-To-Player')
pyplt.xlabel('Game Type')

pyplt.xticks(rotation=45)
pyplt.grid(True)
pyplt.show()

# %% [markdown]
# ### 4. Word Cloud

# %% [markdown]
# #### Exhibit A -- For Game Themes

# %%
themes_for_plot = (GameAttributes_DF['Theme'].str.split(', ').explode()).value_counts()

# Plotting the Cloud for Themes
wordcloud_plot = WordCloud(height=400, width=800, background_color='white').generate_from_frequencies(themes_for_plot)
pyplt.figure(figsize=(10, 5))
pyplt.imshow(wordcloud_plot, interpolation='lanczos')
pyplt.axis('off')
pyplt.title('Word Cloud of Popular Game Themes\n\n\n')
pyplt.show()

# %% [markdown]
# #### Exhibit B -- For Game Genres

# %%
themes_for_plot = (GameAttributes_DF['Genre'].str.split(', ').explode()).value_counts()

# Plotting the Cloud for Genres
wordcloud_plot = WordCloud(height=400, width=800, background_color='white').generate_from_frequencies(themes_for_plot)
pyplt.figure(figsize=(10, 5))
pyplt.imshow(wordcloud_plot, interpolation='lanczos')
pyplt.axis('off')
pyplt.title('Word Cloud of Popular Game Genres\n\n\n')
pyplt.show()
